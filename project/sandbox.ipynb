# %%
import pandas as pd
from sklearn.externals import joblib
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# c:\python36\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df_dict = {'a':[0.5, 0.1, 0.001, 3.7], 'b':[2, 4, 8, 16]}
df = pd.DataFrame.from_dict(df_dict)
df.head()
# Out:
#        a   b
# 0  0.500   2
# 1  0.100   4
# 2  0.001   8
# 3  3.700  16

# %%
little = {'a':[300], 'b':[0.05]}
df_little = pd.DataFrame.from_dict(little)#, orient='index', columns=['val'])#df_little = df_little.T
df_little.head()
# Out:
#      a     b
# 0  300  0.05

# %%
import numpy as np

# %%
df_little = np.asarray([300., 0.05]).reshape(1, -1)

# %%
cos_sim = df.apply(lambda row: cosine_similarity(row.values.reshape(1, -1), df_little)[0][0], axis=1)

# %%
cos_sim
# Out:
# 0    0.242697
# 1    0.025159
# 2    0.000292
# 3    0.225467
# dtype: float64

# %%
cos_sim = pd.DataFrame(cos_sim, columns=['val'])

# %%
cos_sim.head()
# Out:
#         val
# 0  0.242697
# 1  0.025159
# 2  0.000292
# 3  0.225467

# %%
best_cos_sim
# Out:
#          val  test_  test_2
# id
# 0   0.242697      0       0
# 3   0.225467      3      81

# %%
best_cos_sim['test_'] = best_cos_sim.index

# %%
best_cos_sim['test_2'] = best_cos_sim['test_'].apply(lambda x: x**4)

# %%
best_cos_sim.loc[3,'test_2']
# Out:
# 81

# %%
best_cos_sim = best_cos_sim.drop(['test_'], axis=1)

# %%
d_ = {}
for idx, row in best_cos_sim.iterrows():
    d_[idx] = [row[0], row[1]]

# %%
d_
# Out:
# {0: [0.24269731208222786, 0.0], 3: [0.225466585927469, 81.0]}

# %%
d = best_cos_sim.values.tolist()

# %%
d
# Out:
# [[0.24269731208222786, 0.0, 0.0], [0.225466585927469, 3.0, 81.0]]

# %%
best_cos_sim = cos_sim.nlargest(2, 'val')
best_cos_sim.index.name = 'id'
best_cos_sim
# Out:
#          val
# id
# 0   0.242697
# 3   0.225467

# %%
vec = joblib.load('tf_idf_vectorizer.pkl')

# %%
query = 'россия священный наш держава'
q = vec.transform([query])
q = pd.DataFrame(q.toarray(), columns=vec.get_feature_names())
q

# %%
df = pd.DataFrame.from_csv('bm25_index.csv', index_col=None)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     абстрактный  адрес     азиат  английский  астрология  база     белый  \
# 0      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 1      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 2      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 3      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 4      0.000000    0.0  0.000000    0.000000    5.505534   0.0  0.000000
# 5      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 6      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 7      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 8      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 9      0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 10     0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# 11     0.000000    0.0  0.000000    0.000000    0.000000   0.0  0.000000
# ...
